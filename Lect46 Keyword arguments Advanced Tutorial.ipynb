# %%
import pandas as pd
  #working with dataframes, similar to excel, headers, etc
#Seaborn (lect 44) imports
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Method #1 specify full path to file
# "C:\Users\sarah\Desktop\Udemy\Pythoncourse\P4-Demographic-Data.csv"

# %%
#Windows  don't forget double slashes to avoid escape character issue
stats = pd.read_csv('C:\\Users\\sarah\\Desktop\\Udemy\\Pythoncourse\\P4-Demographic-Data.csv')

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# method 2
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\sarah

# %%
#If you had put it in the above folder(where it saves notebook), you don't need to give path

# %%
#mess up, change back
os.chdir('C:\\Users\\sarah\\Desktop\\Udemy\\Pythoncourse')

# %%
print(os.getcwd())
# Out:
# C:\Users\sarah\Desktop\Udemy\Pythoncourse

# %%
stat2 = pd.read_csv('P4-Demographic-Data.csv')

# %%
# explore dataframe 1.
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#2 Number of rows
len(stats)  #195 rows imported
# Out:
# 195

# %%
#3 See columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4 NUMBER OF colunms
len(stats.columns)
# Out:
# 5

# %%
# top rows
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
stats.tail(6)   # head and
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#7 info on the columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns=['a','b','c','d','e']

# %%
stats.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
stats.columns=['Country Name', 'Country Code', 'Birth rate', 'Internet users',  
       'Income Group']
# In Jupyter Notebook can continue even with newline , but regular python need a \

# %%
stats.columns=['CountryName', 'CountryCode',\
               'Birthrate', 'Internetusers','IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
# 2 parts, Rows, columns, combination
stats[21:26] #every row new entry of data so it new rows
# Out:
#    CountryName CountryCode  Birthrate  Internetusers          IncomeGroup
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income

# %%
stats[:5]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Reverse
stats[::-20]  #to reverse reassign stats=stats[::-1]
# Out:
#               CountryName CountryCode  Birthrate  Internetusers  \
# 194              Zimbabwe         ZWE     35.715          18.50
# 174   Trinidad and Tobago         TTO     14.590          63.80
# 154          Sierra Leone         SLE     36.729           1.70
# 134                  Oman         OMN     20.419          66.45
# 114        Macedonia, FYR         MKD     11.222          65.24
# 94               Kiribati         KIR     29.044          11.50
# 74   Hong Kong SAR, China         HKG      7.900          74.20
# 54                Estonia         EST     10.300          79.40
# 34          Cote d'Ivoire         CIV     37.320           8.40
# 14           Burkina Faso         BFA     40.551           9.10
#
#              IncomeGroup
# 194           Low income
# 174          High income
# 154           Low income
# 134          High income
# 114  Upper middle income
# 94   Lower middle income
# 74           High income
# 54           High income
# ...

# %%
#my fav columns
stats['CountryName']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
x=stats['CountryName'].transpose

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
stats[['CountryName','Birthrate']].head()
# Out:
#             CountryName  Birthrate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
stats[['Birthrate','CountryName']].head()
# Out:
#    Birthrate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
stats.Birthrate     # can't have spaces  ---- only works with 1 column
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
# 5      17.716
# 6      13.308
# 7      16.447
# 8      13.200
# 9       9.400
# 10     18.300
# 11     44.151
# 12     11.200
# 13     36.440
# 14     40.551
# 15     20.142
# 16      9.200
# 17     15.040
# 18     15.339
# 19      9.062
# 20     12.500
# 21     23.092
# 22     10.400
# 23     24.236
# 24     14.931
# 25     12.188
# 26     16.405
# 27     18.134
# 28     25.267
# 29     34.076
#         ...
# 165    18.600
# 166    24.043
# 167    45.745
# 168    36.080
# 169    11.041
# 170    30.792
# 171    21.322
# 172    35.755
# 173    25.409
# 174    14.590
# 175    19.800
# 176    16.836
# 177    39.518
# 178    43.474
# 179    11.100
# 180    14.374
# 181    12.500
# 182    22.500
# 183    16.306
# 184    19.842
# 185    10.700
# 186    15.537
# 187    26.739
# 188    30.394
# 189    26.172
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# ...

# %%
# Combining rows/columns
stats[4:8][['CountryName','Birthrate']]
# Out:
#             CountryName  Birthrate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats[['CountryName','Birthrate']][4:8]
# Out:
#             CountryName  Birthrate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats[['CountryName','Birthrate','Internetusers']][4:8]
# Out:
#             CountryName  Birthrate  Internetusers
# 4  United Arab Emirates     11.044           88.0
# 5             Argentina     17.716           59.9
# 6               Armenia     13.308           41.9
# 7   Antigua and Barbuda     16.447           63.4

# %%
results = stats.Birthrate * stats.Internetusers

# %%
results[4:8]  # results.head() for top 10
# Out:
# 4     971.8720
# 5    1061.1884
# 6     557.6052
# 7    1042.7398
# dtype: float64

# %%
# add col
stats['Mycalc'] = stats.Birthrate * stats.Internetusers

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    Mycalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats['xyz'] = range(1,196)

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    Mycalc  xyz
# 0          High income  808.2516    1
# 1           Low income  207.9927    2
# 2  Upper middle income  878.3135    3
# 3  Upper middle income  736.5644    4
# 4          High income  971.8720    5

# %%
# removing column
stats.drop('Mycalc',1)  #vert axis =0, horizontla (columns)=1  shift tab
# Out:
#                         CountryName CountryCode  Birthrate  Internetusers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
stats=stats.drop('Mycalc',1)

# %%
stats[4:10]
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup  xyz
# 4          High income    5
# 5          High income    6
# 6  Lower middle income    7
# 7          High income    8
# 8          High income    9
# 9          High income   10

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  xyz
# 0          High income    1
# 1           Low income    2
# 2  Upper middle income    3
# 3  Upper middle income    4
# 4          High income    5

# %%
Filter=stats.Internetusers<2
Filter.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Internetusers, dtype: bool

# %%
Filter=stats.Internetusers<90
stats[~Filter]
# Out:
#        CountryName CountryCode  Birthrate  Internetusers  IncomeGroup  xyz
# 17         Bahrain         BHR      15.04       90.00004  High income   18
# 22         Bermuda         BMU      10.40       95.30000  High income   23
# 47         Denmark         DNK      10.00       94.62970  High income   48
# 56         Finland         FIN      10.70       91.51440  High income   57
# 84         Iceland         ISL      13.40       96.54680  High income   85
# 102  Liechtenstein         LIE       9.20       93.80000  High income  103
# 106     Luxembourg         LUX      11.30       93.77650  High income  107
# 130    Netherlands         NLD      10.20       93.95640  High income  131
# 131         Norway         NOR      11.60       95.05340  High income  132
# 163         Sweden         SWE      11.80       94.78360  High income  164

# %%
Filterx=stats.Internetusers<90
stats[~Filterx]
# Out:
#        CountryName CountryCode  Birthrate  Internetusers  IncomeGroup  xyz
# 17         Bahrain         BHR      15.04       90.00004  High income   18
# 22         Bermuda         BMU      10.40       95.30000  High income   23
# 47         Denmark         DNK      10.00       94.62970  High income   48
# 56         Finland         FIN      10.70       91.51440  High income   57
# 84         Iceland         ISL      13.40       96.54680  High income   85
# 102  Liechtenstein         LIE       9.20       93.80000  High income  103
# 106     Luxembourg         LUX      11.30       93.77650  High income  107
# 130    Netherlands         NLD      10.20       93.95640  High income  131
# 131         Norway         NOR      11.60       95.05340  High income  132
# 163         Sweden         SWE      11.80       94.78360  High income  164

# %%
Filter2=stats.Birthrate>40
stats[Filter2].head()
# Out:
#       CountryName CountryCode  Birthrate  Internetusers          IncomeGroup  \
# 2          Angola         AGO     45.985           19.1  Upper middle income
# 11        Burundi         BDI     44.151            1.3           Low income
# 14   Burkina Faso         BFA     40.551            9.1           Low income
# 65    Gambia, The         GMB     42.525           14.0           Low income
# 115          Mali         MLI     44.138            3.5           Low income
#
#      xyz
# 2      3
# 11    12
# 14    15
# 65    66
# 115  116

# %%
stats[stats.Birthrate>40].head()
# Out:
#       CountryName CountryCode  Birthrate  Internetusers          IncomeGroup  \
# 2          Angola         AGO     45.985           19.1  Upper middle income
# 11        Burundi         BDI     44.151            1.3           Low income
# 14   Burkina Faso         BFA     40.551            9.1           Low income
# 65    Gambia, The         GMB     42.525           14.0           Low income
# 115          Mali         MLI     44.138            3.5           Low income
#
#      xyz
# 2      3
# 11    12
# 14    15
# 65    66
# 115  116

# %%
#combining filters
stats[(stats.Birthrate>40) & (stats.Internetusers<2)].head()  #use & for bitwise - a lot of explanation
# Out:
#     CountryName CountryCode  Birthrate  Internetusers IncomeGroup  xyz
# 11      Burundi         BDI     44.151            1.3  Low income   12
# 127       Niger         NER     49.661            1.7  Low income  128
# 156     Somalia         SOM     43.891            1.5  Low income  157

# %%
#another one
stats[stats.IncomeGroup=="High income"].head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  IncomeGroup  \
# 0                 Aruba         ABW     10.244           78.9  High income
# 4  United Arab Emirates         ARE     11.044           88.0  High income
# 5             Argentina         ARG     17.716           59.9  High income
# 7   Antigua and Barbuda         ATG     16.447           63.4  High income
# 8             Australia         AUS     13.200           83.0  High income
#
#    xyz
# 0    1
# 4    5
# 5    6
# 7    8
# 8    9

# %%
#how to get unique catagories
stats.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
stats[stats.CountryName=="Malta"]
# Out:
#     CountryName CountryCode  Birthrate  Internetusers  IncomeGroup  xyz
# 116       Malta         MLT        9.5        68.9138  High income  117

# %%
stats.iat[2,2]
# Out:
# 45.985

# %%
stats.head()
# Out:
#             CountryName CountryCode  Birthrate  Internetusers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  xyz
# 0          High income    1
# 1           Low income    2
# 2  Upper middle income    3
# 3  Upper middle income    4
# 4          High income    5

# %%
# .at for labels, even integers are labels
# .iat for integer locations
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2,'Birthrate']
# Out:
# 45.985

# %%
#why we need .at.
sub10=stats[::10]
sub10
# Out:
#      CountryName CountryCode  Birthrate  Internetusers          IncomeGroup  \
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
# Out:
# 'Libya'

# %%
sub10.at[10,'CountryName']  #at looks for labels, label 10
# Out:
# 'Azerbaijan'

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'Birthrate', 'Internetusers',
#        'IncomeGroup', 'xyz'],
#       dtype='object')

# %%
# Seaborn
# Distribution
import warnings
plt.rcParams['figure.figsize']=8,4
warnings.filterwarnings('ignore')
vis1 = sns.distplot(stats["Internetusers"], bins=30) #shift tab after comma will tell info

# %%
vis2=sns.boxplot(data=stats, x="IncomeGroup", y="Birthrate")

# %%
#Seaboarn galary

# %%
vis3=sns.lmplot(x='Internetusers', y='Birthrate',data=stats, fit_reg=False)

# %%
vis3=sns.lmplot(x='Internetusers', y='Birthrate',data=stats, fit_reg=False, hue='IncomeGroup', size=6, aspect=1.4
            )

# %%
# Lect46 Keyword arguments Advanced Tutorial

# %%
# marker size shift tab, dictionaries, at bottom, mentions scatter_kws, 
# which passes to plt (pyplot) the parameter switches as dictionary.

# %%
vis3=sns.lmplot(x='Internetusers', y='Birthrate',data=stats, fit_reg=False, hue='IncomeGroup', size=6, aspect=1.4, \
                scatter_kws={"s":110, "marker":"x", "label":"bc access, or internet access, or procreation drive, or.."})

# %%
# not sure why other switches aren't showing up, but it's late...
