# %%
#Dear Student,
#
#Welcome to the world of Basketball Data!
#I'm sure you will enjoy this section of the Python Programming course.
#
#Instructions for this dataset:
# Simply copy ALL the lines in this script by pressing 
# CTRL+A on Windows or CMND+A on Mac and run the Jupyter cell
# Once you have executed the commands the following objects
# will be created:
# Matrices:
# - Salary
# - Games
# - MinutesPlayed
# - FieldGoals
# - FieldGoalAttempts
# - Points
# Lists:
# - Players
# - Seasons
# Dictionaries:
# - Sdict
# - Pdict
#We will understand these inside the course.
#
#Sincerely,
#Kirill Eremenko
#www.superdatascience.com

#Copyright: These datasets were prepared using publicly available data.
#           However, theses scripts are subject to Copyright Laws. 
#           If you wish to use these Python scripts outside of the Python Programming Course
#           by Kirill Eremenko, you may do so by referencing www.superdatascience.com in your work.

#Comments:
#Seasons are labeled based on the first year in the season
#E.g. the 2012-2013 season is preseneted as simply 2012

#Notes and Corrections to the data:
#Kevin Durant: 2006 - College Data Used
#Kevin Durant: 2005 - Proxied With 2006 Data
#Derrick Rose: 2012 - Did Not Play
#Derrick Rose: 2007 - College Data Used
#Derrick Rose: 2006 - Proxied With 2007 Data
#Derrick Rose: 2005 - Proxied With 2007 Data

#Import numpy
import numpy as np

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]
#Matrix
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]
#Matrix
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])

#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])

# %%
#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]

#Free Throws
KobeBryant_FT = [696,667,623,483,439,483,381,525,18,196]
JoeJohnson_FT = [261,235,316,299,220,195,158,132,159,141]
LeBronJames_FT = [601,489,549,594,593,503,387,403,439,375]
CarmeloAnthony_FT = [573,459,464,371,508,507,295,425,459,189]
DwightHoward_FT = [356,390,529,504,483,546,281,355,349,143]
ChrisBosh_FT = [474,463,472,504,470,384,229,241,223,179]
ChrisPaul_FT = [394,292,332,455,161,337,260,286,295,289]
KevinDurant_FT = [209,209,391,452,756,594,431,679,703,146]
DerrickRose_FT = [146,146,146,197,259,476,194,0,27,152]
DwayneWade_FT = [629,432,354,590,534,494,235,308,189,284]

#Matrix
#
# <put your code here>
#

#Free Throw Attempts
KobeBryant_FTA = [819,768,742,564,541,583,451,626,21,241]
JoeJohnson_FTA = [330,314,379,362,269,243,186,161,195,176]
LeBronJames_FTA = [814,701,771,762,773,663,502,535,585,528]
CarmeloAnthony_FTA = [709,568,590,468,612,605,367,512,541,237]
DwightHoward_FTA = [598,666,897,849,816,916,572,721,638,271]
ChrisBosh_FTA = [581,590,559,617,590,471,279,302,272,232]
ChrisPaul_FTA = [465,357,390,524,190,384,302,323,345,321]
KevinDurant_FTA = [256,256,448,524,840,675,501,750,805,171]
DerrickRose_FTA = [205,205,205,250,338,555,239,0,32,187]
DwayneWade_FTA = [803,535,467,771,702,652,297,425,258,370]

#Matrix
#
# <put your code here>
#

# %%
print(Salary)
# Out:
# [[15946875 17718750 19490625 21262500 23034375 24806250 25244493 27849149
#   30453805 23500000]
#  [12000000 12744189 13488377 14232567 14976754 16324500 18038573 19752645
#   21466718 23180790]
#  [ 4621800  5828090 13041250 14410581 15779912 14500000 16022500 17545000
#   19067500 20644400]
#  [ 3713640  4694041 13041250 14410581 15779912 17149243 18518574 19450000
#   22407474 22458000]
#  [ 4493160  4806720  6061274 13758000 15202590 16647180 18091770 19536360
#   20513178 21436271]
#  [ 3348000  4235220 12455000 14410581 15779912 14500000 16022500 17545000
#   19067500 20644400]
#  [ 3144240  3380160  3615960  4574189 13520500 14940153 16359805 17779458
#   18668431 20068563]
#  [       0        0  4171200  4484040  4796880  6053663 15506632 16669630
#   17832627 18995624]
#  [       0        0        0  4822800  5184480  5546160  6993708 16402500
#   17632688 18862875]
#  [ 3031920  3841443 13041250 14410581 15779912 14200000 15691000 17182000
#   18673000 15000000]]

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 82],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Games[0]  #Kobe
# Out:
# array([80, 77, 82, 82, 73, 82, 58, 78,  6, 35])

# %%
Games[2]
# Out:
# array([79, 78, 75, 81, 76, 79, 62, 76, 77, 69])

# %%
Games[2,9]
# Out:
# 69

# %%
Games[2,-1]
# Out:
# 69

# %%
Games[2][-1]
# Out:
# 69

# %%
# Dictionaries  use curly brackets  -uses keys/labels
dict1={'key1':'val1','key2':'val2','key3':'val3'}

# %%
dict1['key2']
# Out:
# 'val2'

# %%
dict2={'Germany':'I have been here','France':'2','Spain':True}
dict2['France']
# Out:
# '2'

# %%
Pdict['KobeBryant']
# Out:
# 0

# %%
Games
# Out:
# array([[80, 77, 82, 82, 73, 82, 58, 78,  6, 35],
#        [82, 57, 82, 79, 76, 72, 60, 72, 79, 80],
#        [79, 78, 75, 81, 76, 79, 62, 76, 77, 69],
#        [80, 65, 77, 66, 69, 77, 55, 67, 77, 40],
#        [82, 82, 82, 79, 82, 78, 54, 76, 71, 41],
#        [70, 69, 67, 77, 70, 77, 57, 74, 79, 44],
#        [78, 64, 80, 78, 45, 80, 60, 70, 62, 82],
#        [35, 35, 80, 74, 82, 78, 66, 81, 81, 27],
#        [40, 40, 40, 81, 78, 81, 39,  0, 10, 51],
#        [75, 51, 51, 79, 77, 76, 49, 69, 54, 62]])

# %%
Games[0]
# Out:
# array([80, 77, 82, 82, 73, 82, 58, 78,  6, 35])

# %%
Pdict['DerrickRose']
# Out:
# 8

# %%
Games[Pdict['DerrickRose']]
# Out:
# array([40, 40, 40, 81, 78, 81, 39,  0, 10, 51])

# %%
Games[8]
# Out:
# array([40, 40, 40, 81, 78, 81, 39,  0, 10, 51])

# %%
Games[Pdict['DerrickRose'],6]
# Out:
# 39

# %%
Games[Pdict['DerrickRose']][Sdict['2011']]
# Out:
# 39

# %%
Points[Pdict['JoeJohnson']][Sdict['2012']]
# Out:
# 1170

# %%
Points[Pdict['JoeJohnson']]
# Out:
# array([1653, 1426, 1779, 1688, 1619, 1312, 1129, 1170, 1245, 1154])

# %%
##------------------
#   Matrix operations
print(Pdict["LeBronJames"])
print(Sdict["2009"])
# Out:
# 2
# 4

# %%
Salary[Pdict["LeBronJames"]][4]
# Out:
# 15779912

# %%
import warnings
warnings.filterwarnings('ignore')  #not error on divide by zero (nan)

# %%
FieldGoalsPerGame=np.matrix.round(FieldGoals/Games)
FieldGoalsPerGame
# Out:
# array([[12., 11.,  9., 10., 10.,  9., 10.,  9.,  5.,  8.],
#        [ 8.,  9.,  8.,  8.,  8.,  7.,  7.,  6.,  6.,  6.],
#        [11., 10., 11., 10., 10., 10., 10., 10., 10.,  9.],
#        [ 9., 11.,  9.,  8., 10.,  9.,  8., 10., 10.,  9.],
#        [ 6.,  6.,  7.,  7.,  6.,  8.,  8.,  6.,  7.,  6.],
#        [ 8.,  8.,  8.,  8.,  9.,  7.,  7.,  7.,  6.,  8.],
#        [ 5.,  6.,  8.,  8.,  7.,  5.,  7.,  6.,  7.,  7.],
#        [ 9.,  9.,  7.,  9., 10.,  9., 10.,  9., 10.,  9.],
#        [ 5.,  5.,  5.,  7.,  9.,  9.,  8., nan,  6.,  7.],
#        [ 9.,  9.,  9., 11.,  9.,  9.,  8.,  8.,  8.,  8.]])

# %%
FieldGoalsPerGame[Pdict["KobeBryant"]][Sdict["2009"]]
# Out:
# 10.0

# %%
np.matrix.round(MinutesPlayed/Games)
# Out:
# array([[41., 41., 39., 36., 39., 34., 38., 39., 30., 34.],
#        [41., 41., 41., 40., 38., 35., 35., 37., 33., 35.],
#        [43., 41., 40., 38., 39., 39., 38., 38., 38., 36.],
#        [37., 38., 36., 34., 38., 36., 34., 37., 39., 36.],
#        [37., 37., 38., 36., 35., 38., 38., 36., 34., 30.],
#        [39., 39., 36., 38., 36., 36., 35., 33., 32., 35.],
#        [36., 37., 38., 38., 38., 36., 36., 33., 35., 35.],
#        [36., 36., 35., 39., 40., 39., 39., 39., 39., 34.],
#        [29., 29., 29., 37., 37., 37., 35., nan, 31., 30.],
#        [39., 38., 38., 39., 36., 37., 33., 35., 33., 32.]])

# %%
MinutesPlayed
# Out:
# array([[3277, 3140, 3192, 2960, 2835, 2779, 2232, 3013,  177, 1207],
#        [3340, 2359, 3343, 3124, 2886, 2554, 2127, 2642, 2575, 2791],
#        [3361, 3190, 3027, 3054, 2966, 3063, 2326, 2877, 2902, 2493],
#        [2941, 2486, 2806, 2277, 2634, 2751, 1876, 2482, 2982, 1428],
#        [3021, 3023, 3088, 2821, 2843, 2935, 2070, 2722, 2396, 1223],
#        [2751, 2658, 2425, 2928, 2526, 2795, 2007, 2454, 2531, 1556],
#        [2808, 2353, 3006, 3002, 1712, 2880, 2181, 2335, 2171, 2857],
#        [1255, 1255, 2768, 2885, 3239, 3038, 2546, 3119, 3122,  913],
#        [1168, 1168, 1168, 3000, 2871, 3026, 1375,    0,  311, 1530],
#        [2892, 1931, 1954, 3048, 2792, 2823, 1625, 2391, 1775, 1971]])

# %%
FieldGoalAttempts/FieldGoals
# Out:
# array([[2.22188139, 2.16113161, 2.18064516, 2.14      , 2.19134078,
#         2.21486486, 2.32752613, 2.16124661, 2.35483871, 2.68045113],
#        [2.20727848, 2.125     , 2.3137558 , 2.29032258, 2.18267717,
#         2.25875486, 2.20094563, 2.36404494, 2.2034632 , 2.29820628],
#        [2.08342857, 2.09974093, 2.06801008, 2.04435995, 1.98958333,
#         1.9591029 , 1.88244767, 1.76993464, 1.76401565, 2.04967949],
#        [2.07936508, 2.10274964, 2.03434066, 2.25607477, 2.18313953,
#         2.19736842, 2.32426304, 2.22571001, 2.21130552, 2.25139665],
#        [1.88247863, 1.65969582, 1.67066895, 1.74821429, 1.63529412,
#         1.68659128, 1.74519231, 1.72978723, 1.69133192, 1.68525896],
#        [1.97996357, 2.01473297, 2.02564103, 2.05365854, 1.93      ,
#         2.01526718, 2.05343511, 1.87010309, 1.93699187, 2.17201166],
#        [2.32678133, 2.28608924, 2.04920635, 1.9889065 , 2.02866242,
#         2.15813953, 2.09411765, 2.0776699 , 2.14285714, 2.05985915],
# ...

# %%
FieldGoalAttempts[Pdict["KobeBryant"]]/FieldGoals[0]
# Out:
# array([2.22188139, 2.16113161, 2.18064516, 2.14      , 2.19134078,
#        2.21486486, 2.32752613, 2.16124661, 2.35483871, 2.68045113])

# %%
#--------------Visualization

# %%
np.matrix.round(FieldGoals/FieldGoalAttempts,2)*100  #2 rounds 2 places (*100 percent)
# Out:
# array([[45., 46., 46., 47., 46., 45., 43., 46., 42., 37.],
#        [45., 47., 43., 44., 46., 44., 45., 42., 45., 44.],
#        [48., 48., 48., 49., 50., 51., 53., 56., 57., 49.],
#        [48., 48., 49., 44., 46., 46., 43., 45., 45., 44.],
#        [53., 60., 60., 57., 61., 59., 57., 58., 59., 59.],
#        [51., 50., 49., 49., 52., 50., 49., 53., 52., 46.],
#        [43., 44., 49., 50., 49., 46., 48., 48., 47., 49.],
#        [47., 47., 43., 48., 48., 46., 50., 51., 50., 51.],
#        [48., 48., 48., 48., 49., 45., 43., nan, 35., 40.],
#        [49., 49., 47., 49., 48., 50., 50., 52., 55., 47.]])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#matplotlib inline # shown in Jupyter not separate window
plt.plot(Salary[0])

# %%
Salary[0]
# Out:
# array([15946875, 17718750, 19490625, 21262500, 23034375, 24806250,
#        25244493, 27849149, 30453805, 23500000])

# %%
plt.plot(Salary[0],c='Purple', ls='--',marker='*',ms=7)

# %%
plt.plot(Salary[0],c='Pink', ls='--',marker='s',ms=10)
plt.show()

# %%
plt.rcParams['figure.figsize']=8,4
plt.plot(Salary[0],c='Purple', ls='--',marker='x',ms=10)
plt.show()

# %%
plt.rcParams['figure.figsize']=8,4
plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
plt.plot(Salary[0],c='Blue', ls='--',marker='o',ms=10, label=Players[0])
plt.show()

# %%
plt.rcParams['figure.figsize']=8,4
plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
plt.plot(Salary[0],c='Blue', ls='--',marker='o',ms=10, label=Players[0])
plt.plot(Salary[1],c='Magenta', ls=':',marker='+',ms=6, label=Players[0])
plt.show()

# %%
# google/ matplotlib.org  to see options- well hard to find, just google
plt.rcParams['figure.figsize']=8,4
plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
plt.plot(Salary[0],c='Blue', ls='--',marker='o',ms=5, label=Players[0])
plt.plot(Salary[1],c='Magenta', ls=':',marker='+',ms=6, label=Players[1])
plt.plot(Salary[2],c='Black', ls=':',marker='+',ms=6, label=Players[2])
plt.plot(Salary[3],c='Green', ls='-',marker='<',ms=8, label=Players[3])
plt.plot(Salary[4],c='Red', ls='--',marker='o',ms=6, label=Players[4])
plt.plot(Salary[5],c='Black', ls=':',marker='+',ms=6, label=Players[5])
plt.plot(Salary[6],c='Pink', ls=':',marker='^',ms=6, label=Players[6])
plt.plot(Salary[7],c='Yellow', ls='-',marker='>',ms=8, label=Players[7])
plt.plot(Salary[8],c='Pink', ls=':',marker='s',ms=6, label=Players[8])
plt.plot(Salary[9],c='Yellow', ls='-',marker='D',ms=6
         , label=Players[9])
plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
plt.show()

# %%
plt.rcParams['figure.figsize']=8,4
plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
plt.plot(Games[0],c='Blue', ls='--',marker='o',ms=5, label=Players[0])
plt.plot(Games[1],c='Magenta', ls=':',marker='+',ms=6, label=Players[1])
plt.plot(Games[2],c='Black', ls=':',marker='+',ms=6, label=Players[2])
plt.plot(Games[3],c='Green', ls='-',marker='<',ms=8, label=Players[3])
plt.plot(Games[4],c='Red', ls='--',marker='o',ms=6, label=Players[4])
plt.plot(Games[5],c='Black', ls=':',marker='+',ms=6, label=Players[5])
plt.plot(Games[6],c='Pink', ls=':',marker='^',ms=6, label=Players[6])
plt.plot(Games[7],c='Yellow', ls='-',marker='>',ms=8, label=Players[7])
plt.plot(Games[8],c='Pink', ls=':',marker='s',ms=6, label=Players[8])
plt.plot(Games[9],c='Yellow', ls='-',marker='D',ms=6, label=Players[9])
plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
plt.show()

# %%
# Our own Function

# %%
def myplot(playerlist):
    for name in playerlist:
        plt.plot(Games[Pdict[name]],c='Blue', ls='--',marker='o',ms=5, label=name)
  
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(["KobeBryant","LeBronJames","DerrickRose"])

# %%
col=["orchid","lavender","salmon","fuchsia","lightblue","Pink","Yellow","Brown","Purple","Orange"]
mark=["+","<",">","^","o","*","x","s","d","1","p"]
#https://matplotlib.org/3.1.0/api/markers_api.html
#https://matplotlib.org/users/colors.html

# %%
def myplot(playerlist):
    for name in playerlist:
        plt.plot(Games[Pdict[name]],c=col[Pdict[name]], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(["KobeBryant","LeBronJames","DerrickRose"])

# %%
myplot(Players)

# %%
len(Players)
# Out:
# 10

# %%
# Advanced Function Design

# %%
Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"g","DwayneWade":"b"}

# %%
def myplot(playerlist):
    Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"g","DwayneWade":"b"}
    for name in playerlist:
        plt.plot(Games[Pdict[name]],c=Col[name], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(Players)

# %%
def myplot(playerlist):
    Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"g","DwayneWade":"b"}
    Mrk={"KobeBryant":"1","JoeJohnson":"2","LeBronJames":"3","CarmeloAnthony":"4","DwightHoward":"8","ChrisBosh":".","ChrisPaul":",","KevinDurant":"X","DerrickRose":"p","DwayneWade":"s"}
    for name in playerlist:
        plt.plot(Games[Pdict[name]],c=Col[name], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(Players)

# %%
# this way seems harder than 104 105  =

# %%
def myplot(data,playerlist):
    Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"pink","DwayneWade":"b"}
    Mrk={"KobeBryant":"1","JoeJohnson":"2","LeBronJames":"3","CarmeloAnthony":"4","DwightHoward":"8","ChrisBosh":".","ChrisPaul":",","KevinDurant":"X","DerrickRose":"p","DwayneWade":"s"}
    for name in playerlist:
        plt.plot(data[Pdict[name]],c=Col[name], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(Games,Players)

# %%
myplot(Salary,Players)

# %%
def myplot(data,playerlist=Players):
    Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"pink","DwayneWade":"b"}
    Mrk={"KobeBryant":"1","JoeJohnson":"2","LeBronJames":"3","CarmeloAnthony":"4","DwightHoward":"8","ChrisBosh":".","ChrisPaul":",","KevinDurant":"X","DerrickRose":"p","DwayneWade":"s"}
    for name in playerlist:
        plt.plot(data[Pdict[name]],c=Col[name], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(Points)

# %%
myplot(Points, ["KobeBryant"])

# %%
myplot(Salary/Points)

# %%
myplot(FieldGoals/MinutesPlayed)

# %%
myplot(FieldGoals/FieldGoalAttempts/MinutesPlayed)

# %%
myplot(Points/FieldGoals)

# %%
# missed field goals give chance at turnover
# missed shots per minute
myplot((FieldGoalAttempts-FieldGoals)/MinutesPlayed)

# %%
#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]
#Matrix
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]
#Matrix
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])

#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])

# %%
# Matrices HW Section

# %%
#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]

#Free Throws
KobeBryant_FT = [696,667,623,483,439,483,381,525,18,196]
JoeJohnson_FT = [261,235,316,299,220,195,158,132,159,141]
LeBronJames_FT = [601,489,549,594,593,503,387,403,439,375]
CarmeloAnthony_FT = [573,459,464,371,508,507,295,425,459,189]
DwightHoward_FT = [356,390,529,504,483,546,281,355,349,143]
ChrisBosh_FT = [474,463,472,504,470,384,229,241,223,179]
ChrisPaul_FT = [394,292,332,455,161,337,260,286,295,289]
KevinDurant_FT = [209,209,391,452,756,594,431,679,703,146]
DerrickRose_FT = [146,146,146,197,259,476,194,0,27,152]
DwayneWade_FT = [629,432,354,590,534,494,235,308,189,284]

#Matrix
#
FreeThrows = np.array([KobeBryant_FT, JoeJohnson_FT, LeBronJames_FT, CarmeloAnthony_FT, DwightHoward_FT, ChrisBosh_FT, ChrisPaul_FT, KevinDurant_FT, DerrickRose_FT, DwayneWade_FT])             
                  
#

#Free Throw Attempts
KobeBryant_FTA = [819,768,742,564,541,583,451,626,21,241]
JoeJohnson_FTA = [330,314,379,362,269,243,186,161,195,176]
LeBronJames_FTA = [814,701,771,762,773,663,502,535,585,528]
CarmeloAnthony_FTA = [709,568,590,468,612,605,367,512,541,237]
DwightHoward_FTA = [598,666,897,849,816,916,572,721,638,271]
ChrisBosh_FTA = [581,590,559,617,590,471,279,302,272,232]
ChrisPaul_FTA = [465,357,390,524,190,384,302,323,345,321]
KevinDurant_FTA = [256,256,448,524,840,675,501,750,805,171]
DerrickRose_FTA = [205,205,205,250,338,555,239,0,32,187]
DwayneWade_FTA = [803,535,467,771,702,652,297,425,258,370]

#Matrix
#
FreeThrowAttempts = np.array([KobeBryant_FTA,JoeJohnson_FT, LeBronJames_FTA, CarmeloAnthony_FTA, DwightHoward_FTA, ChrisBosh_FTA, ChrisPaul_FTA, KevinDurant_FTA, DerrickRose_FTA, DwayneWade_FTA])             
#

# %%
import warnings
warnings.filterwarnings('ignore')  #not error on divide by zero (nan)
import numpy as np
import matplotlib.pyplot as plt
col=["orchid","lavender","salmon","fuchsia","lightblue","Pink","Yellow","Brown","Purple","Orange","Mauve"]
mark=["+","<",">","^","o","*","x","s","d","1","p"]
#https://matplotlib.org/3.1.0/api/markers_api.html
#https://matplotlib.org/users/colors.html

# %%
def myplot(data,playerlist=Players):
    #Col={"KobeBryant":"Purple","JoeJohnson":"Pink","LeBronJames":"Yellow","CarmeloAnthony":"Grey","DwightHoward":"orchid","ChrisBosh":"c","ChrisPaul":"m","KevinDurant":"r","DerrickRose":"pink","DwayneWade":"b"}
    #Mrk={"KobeBryant":"1","JoeJohnson":"2","LeBronJames":"3","CarmeloAnthony":"4","DwightHoward":"8","ChrisBosh":".","ChrisPaul":",","KevinDurant":"X","DerrickRose":"p","DwayneWade":"s"}
    for name in playerlist:
        #plt.plot(data[Pdict[name]],c=Col[name], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
        plt.plot(data[Pdict[name]],c=col[Pdict[name]], ls='--',marker=mark[Pdict[name]],ms=5, label=name)
        
    plt.xticks(list(range(0,10)),Seasons, rotation='vertical')
    plt.legend(loc='upper left',bbox_to_anchor=(1,1)) #1,0 will put lower right
    plt.show()

# %%
myplot(FreeThrows)

# %%
myplot(FreeThrowAttempts)

# %%
#  Free throw Attempts per game

# %%
myplot(FreeThrowAttempts/Games)

# %%
#Accuracy
myplot(FreeThrows/FreeThrowAttempts*100)

# %%
# Style:  3point distance shots or 2point closer shots
myplot((Points-FreeThrows)/FieldGoals)
